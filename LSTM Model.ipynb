# %%
from music21 import converter, instrument, note, chord
# import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation
from keras.utils import np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
import mido
import glob, pickle
import sys
import numpy as np
import os
import sklearn
import matplotlib.pyplot as plt

# %%
def train_network():
    """ Train a Neural Network to generate music """
    notes = get_notes()

    # get amount of pitch names
    # n_vocab = len(set(np.ndarray.flatten(np.array(notes))))
    unpacked_notes = []
    
    for item in notes:
        unpacked_notes.extend(item)
    
    n_vocab = len(set(unpacked_notes))

    network_input, network_output = prepare_sequences(notes, n_vocab)

    model = create_network(network_input, n_vocab)
    
    np.save("a", network_input)
    np.save("b", network_output)

    return train(model, network_input, network_output)

def get_notes():
    """ Get all the notes and chords from the midi files in the ./midi_songs directory """
    notes = []

    for file in glob.glob("midi_songs/*.mid"):
        midi = converter.parse(file)
        notes_i = []

        print("Parsing %s" % file)

        notes_to_parse = None

        try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse() 
        except: # file has notes in a flat structure
            notes_to_parse = midi.flat.notes

        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes_i.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes_i.append(str(element.pitches[-1])) # take the note with the highest octave? This is a modification
        
        # trim out the excess to standardize the length of the musical piece
        desired_length = len(notes_i) - (len(notes_i) % 50) # 50 will be our input length
        notes.append(notes_i[0:desired_length])

    assert len(notes) == len(glob.glob("midi_songs/*.mid"))
    
    with open('data/notes', 'wb') as filepath:
        pickle.dump(notes, filepath)

    return notes

def prepare_sequences(notes, n_vocab):
    """ Prepare the sequences used by the Neural Network """
    sequence_length = 50
    
    unpacked_notes = []
    
    for item in notes:
        unpacked_notes.extend(item)

    # get all pitch names
    pitchnames = sorted(set(item for item in unpacked_notes))

     # create a dictionary to map pitches to integers
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))

    network_input = []
    network_output = []

    # create input sequences and the corresponding outputs
    for song in notes:
        for i in range(0, len(song) - sequence_length, 1):
            sequence_in = song[i:i + sequence_length]
            sequence_out = song[i + sequence_length]
            network_input.append([note_to_int[char] for char in sequence_in])
            network_output.append(note_to_int[sequence_out])
    
    assert len(network_input) == len(network_output), len(network_input)

    n_patterns = len(network_input)

    # reshape the input into a format compatible with LSTM layers
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    # normalize input
    network_input = network_input / float(n_vocab)

    network_output = np_utils.to_categorical(network_output)

    return (network_input, network_output)

def create_network(network_input, n_vocab):
    """ create the structure of the neural network """
    model = Sequential()
    model.add(LSTM(
        256,
        input_shape=(network_input.shape[1], network_input.shape[2]),
        return_sequences=True
    ))
    #model.add(Dropout(0.3))
    model.add(LSTM(n_vocab))
    #model.add(Dropout(0.3))
    #model.add(LSTM(512))
    #model.add(Dense(256))
    #model.add(Dropout(0.3))
    model.add(Dense(n_vocab))
    model.add(Activation('softmax'))
    rmsprop = optimizers.RMSprop(lr=0.002, rho=0.9, epsilon=None, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=rmsprop, metrics=['accuracy'])

    return model

def train(model, network_input, network_output):
    """ train the neural network """
    filepath = "weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"
    checkpoint = ModelCheckpoint(
        filepath,
        monitor='loss',
        verbose=0,
        save_best_only=True,
        mode='min'
    )
    callbacks_list = [checkpoint]

    history_object = model.fit(network_input, network_output, 
                               epochs=200, batch_size=64,
                               validation_split=0.2,
                               callbacks=None)
    return history_object

# %%
train_network()
# Out:
# Parsing midi_songs/FF8_Shuffle_or_boogie_pc.mid
# Parsing midi_songs/ahead_on_our_way_piano.mid
# Parsing midi_songs/balamb.mid
# Parsing midi_songs/DOS.mid
# Parsing midi_songs/FF3_Battle_(Piano).mid
# Parsing midi_songs/Suteki_Da_Ne_(Piano_Version).mid
# Parsing midi_songs/caitsith.mid
# Parsing midi_songs/sera_.mid
# Parsing midi_songs/ff4-airship.mid
# Parsing midi_songs/ff7themep.mid
# Parsing midi_songs/FFVII_BATTLE.mid
# Parsing midi_songs/electric_de_chocobo.mid
# Parsing midi_songs/Cids.mid
# Parsing midi_songs/FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid
# Parsing midi_songs/AT.mid
# Parsing midi_songs/8.mid
# Parsing midi_songs/sobf.mid
# Parsing midi_songs/redwings.mid
# Parsing midi_songs/roseofmay-piano.mid
# Parsing midi_songs/ff4_piano_collections-main_theme.mid
# Parsing midi_songs/dontbeafraid.mid
# Parsing midi_songs/dayafter.mid
# Parsing midi_songs/FFIX_Piano.mid
# Parsing midi_songs/FFIII_Edgar_And_Sabin_Piano.mid
# Parsing midi_songs/0fithos.mid
# Parsing midi_songs/BlueStone_LastDungeon.mid
# Parsing midi_songs/ff8-lfp.mid
# Parsing midi_songs/rufus.mid
# Parsing midi_songs/Fiend_Battle_(Piano).mid
# Parsing midi_songs/cosmo.mid
# Parsing midi_songs/relmstheme-piano.mid
# Parsing midi_songs/ff11_awakening_piano.mid
# Parsing midi_songs/gerudo.mid
# Parsing midi_songs/Rydia_pc.mid
# Parsing midi_songs/Ff4-BattleLust.mid
# Parsing midi_songs/EyesOnMePiano.mid
# Parsing midi_songs/fortresscondor.mid
# Parsing midi_songs/Still_Alive-1.mid
# Parsing midi_songs/Fyw_piano.mid
# Parsing midi_songs/sandy.mid
# Parsing midi_songs/costadsol.mid
# Parsing midi_songs/decisive.mid
# Parsing midi_songs/braska.mid
# Parsing midi_songs/Gold_Silver_Rival_Battle.mid
# Parsing midi_songs/FF3_Third_Phase_Final_(Piano).mid
# Parsing midi_songs/Eternal_Harvest.mid
# Parsing midi_songs/ff1battp.mid
# Parsing midi_songs/Finalfantasy6fanfarecomplete.mid
# Parsing midi_songs/FFIXQuMarshP.mid
# Parsing midi_songs/bcm.mid
# Epoch 1/200
# 33500/33500 [==============================] - 96s 3ms/sample - loss: 3.9079 - accuracy: 0.0387
# Epoch 2/200
# 33500/33500 [==============================] - 100s 3ms/sample - loss: 3.8213 - accuracy: 0.0670
# Epoch 3/200
# 33500/33500 [==============================] - 97s 3ms/sample - loss: 3.7710 - accuracy: 0.0759
# Epoch 4/200
# 33500/33500 [==============================] - 98s 3ms/sample - loss: 3.7341 - accuracy: 0.0823
# Epoch 5/200
# 33500/33500 [==============================] - 93s 3ms/sample - loss: 3.6811 - accuracy: 0.0932
# Epoch 6/200
# 33500/33500 [==============================] - 93s 3ms/sample - loss: 3.6175 - accuracy: 0.1080
# Epoch 7/200
# 33500/33500 [==============================] - 92s 3ms/sample - loss: 3.5461 - accuracy: 0.1230
# Epoch 8/200
# 33500/33500 [==============================] - 90s 3ms/sample - loss: 3.4729 - accuracy: 0.1360
# Epoch 9/200
# 33500/33500 [==============================] - 89s 3ms/sample - loss: 3.3814 - accuracy: 0.1586
# Epoch 10/200
# 33500/33500 [==============================] - 136s 4ms/sample - loss: 3.2899 - accuracy: 0.1757
# Epoch 11/200
# 33500/33500 [==============================] - 111s 3ms/sample - loss: 3.1946 - accuracy: 0.1909
# Epoch 12/200
# 33500/33500 [==============================] - 116s 3ms/sample - loss: 3.0959 - accuracy: 0.2074
# Epoch 13/200
# 33500/33500 [==============================] - 97s 3ms/sample - loss: 2.9994 - accuracy: 0.2263
# Epoch 14/200
# 33500/33500 [==============================] - 90s 3ms/sample - loss: 2.9115 - accuracy: 0.2398
# Epoch 15/200
# 33500/33500 [==============================] - 108s 3ms/sample - loss: 2.8276 - accuracy: 0.2571
# Epoch 16/200
# 33500/33500 [==============================] - 92s 3ms/sample - loss: 2.7463 - accuracy: 0.2692
# Epoch 17/200
# 33500/33500 [==============================] - 95s 3ms/sample - loss: 2.6674 - accuracy: 0.2840
# Epoch 18/200
# 33500/33500 [==============================] - 98s 3ms/sample - loss: 2.5880 - accuracy: 0.2995
# Epoch 19/200
# 33500/33500 [==============================] - 90s 3ms/sample - loss: 2.5112 - accuracy: 0.3116
# Epoch 20/200
# 33500/33500 [==============================] - 89s 3ms/sample - loss: 2.4447 - accuracy: 0.3260
# Epoch 21/200
# 33500/33500 [==============================] - 90s 3ms/sample - loss: 2.3791 - accuracy: 0.3399
# Epoch 22/200
# 33500/33500 [==============================] - 89s 3ms/sample - loss: 2.3126 - accuracy: 0.3530
# Epoch 23/200
# 33500/33500 [==============================] - 90s 3ms/sample - loss: 2.2428 - accuracy: 0.3717
# Epoch 24/200
# 33500/33500 [==============================] - 93s 3ms/sample - loss: 2.1783 - accuracy: 0.3832
# Epoch 25/200
# 33500/33500 [==============================] - 95s 3ms/sample - loss: 2.1172 - accuracy: 0.4013
# Epoch 26/200
# 33500/33500 [==============================] - 90s 3ms/sample - loss: 2.0536 - accuracy: 0.4138
# Epoch 27/200
# 33500/33500 [==============================] - 89s 3ms/sample - loss: 1.9910 - accuracy: 0.4335
# Epoch 28/200
# 33500/33500 [==============================] - 93s 3ms/sample - loss: 1.9253 - accuracy: 0.4476
# Epoch 29/200
# 33500/33500 [==============================] - 94s 3ms/sample - loss: 1.8668 - accuracy: 0.4641
# Epoch 30/200
# 33500/33500 [==============================] - 93s 3ms/sample - loss: 1.8052 - accuracy: 0.4823
# Epoch 31/200
# 33500/33500 [==============================] - 99s 3ms/sample - loss: 1.7443 - accuracy: 0.4962
# Epoch 32/200
# 33500/33500 [==============================] - 95s 3ms/sample - loss: 1.6869 - accuracy: 0.5164
# Epoch 33/200
# 33500/33500 [==============================] - 95s 3ms/sample - loss: 1.6247 - accuracy: 0.5337
# Epoch 34/200
# 33500/33500 [==============================] - 94s 3ms/sample - loss: 1.5653 - accuracy: 0.5530
# Epoch 35/200
# 33500/33500 [==============================] - 95s 3ms/sample - loss: 1.5077 - accuracy: 0.5717
# Epoch 36/200
# 33500/33500 [==============================] - 96s 3ms/sample - loss: 1.4555 - accuracy: 0.5871
# Epoch 37/200
# 33500/33500 [==============================] - 93s 3ms/sample - loss: 1.3990 - accuracy: 0.6018
# Epoch 38/200
# 33500/33500 [==============================] - 93s 3ms/sample - loss: 1.3419 - accuracy: 0.6191
# Epoch 39/200
# 33500/33500 [==============================] - 92s 3ms/sample - loss: 1.2953 - accuracy: 0.6326
# Epoch 40/200
# 33500/33500 [==============================] - 93s 3ms/sample - loss: 1.2398 - accuracy: 0.6507
# Epoch 41/200
# 33500/33500 [==============================] - 92s 3ms/sample - loss: 1.1889 - accuracy: 0.6657
# Epoch 42/200
# 33500/33500 [==============================] - 93s 3ms/sample - loss: 1.1416 - accuracy: 0.6804
# Epoch 43/200
# 33500/33500 [==============================] - 90s 3ms/sample - loss: 1.0889 - accuracy: 0.6972
# Epoch 44/200
# 33500/33500 [==============================] - 87s 3ms/sample - loss: 1.0484 - accuracy: 0.7098
# Epoch 45/200
# 33500/33500 [==============================] - 91s 3ms/sample - loss: 0.9989 - accuracy: 0.7244
# Epoch 46/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.9561 - accuracy: 0.7390
# Epoch 47/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.9153 - accuracy: 0.7478
# Epoch 48/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.8746 - accuracy: 0.7621
# Epoch 49/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.8394 - accuracy: 0.7711
# Epoch 50/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.7980 - accuracy: 0.7852
# Epoch 51/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.7645 - accuracy: 0.7947
# Epoch 52/200
# 33500/33500 [==============================] - 89s 3ms/sample - loss: 0.7316 - accuracy: 0.8058
# Epoch 53/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.7028 - accuracy: 0.8116
# Epoch 54/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.6729 - accuracy: 0.8213
# Epoch 55/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.6453 - accuracy: 0.8292
# Epoch 56/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.6143 - accuracy: 0.8380
# Epoch 57/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.5919 - accuracy: 0.8450
# Epoch 58/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.5668 - accuracy: 0.8548
# Epoch 59/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.5435 - accuracy: 0.8591
# Epoch 60/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.5222 - accuracy: 0.8639
# Epoch 61/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.4984 - accuracy: 0.8711
# Epoch 62/200
# 33500/33500 [==============================] - 87s 3ms/sample - loss: 0.4814 - accuracy: 0.8765
# Epoch 63/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.4645 - accuracy: 0.8805
# Epoch 64/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.4447 - accuracy: 0.8861
# Epoch 65/200
# 33500/33500 [==============================] - 83s 2ms/sample - loss: 0.4275 - accuracy: 0.8916
# Epoch 66/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.4098 - accuracy: 0.8972
# Epoch 67/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.3940 - accuracy: 0.9017
# Epoch 68/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.3853 - accuracy: 0.9038
# Epoch 69/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.3659 - accuracy: 0.9098
# Epoch 70/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.3579 - accuracy: 0.9117
# Epoch 71/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.3446 - accuracy: 0.9155
# Epoch 72/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.3339 - accuracy: 0.9179
# Epoch 73/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.3220 - accuracy: 0.9214
# Epoch 74/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.3083 - accuracy: 0.9248
# Epoch 75/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.3031 - accuracy: 0.9254
# Epoch 76/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.2967 - accuracy: 0.9274
# Epoch 77/200
# 33500/33500 [==============================] - 92s 3ms/sample - loss: 0.2844 - accuracy: 0.9311
# Epoch 78/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.2755 - accuracy: 0.9327
# Epoch 79/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.2829 - accuracy: 0.9328
# Epoch 80/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.2747 - accuracy: 0.9323
# Epoch 81/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.2548 - accuracy: 0.9382
# Epoch 82/200
# 33500/33500 [==============================] - 84s 3ms/sample - loss: 0.2529 - accuracy: 0.9395
# Epoch 83/200
# 33500/33500 [==============================] - 84s 3ms/sample - loss: 0.2401 - accuracy: 0.9431
# Epoch 84/200
# 33500/33500 [==============================] - 84s 3ms/sample - loss: 0.2399 - accuracy: 0.9423
# Epoch 85/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.2299 - accuracy: 0.9446
# Epoch 86/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.2231 - accuracy: 0.9464
# Epoch 87/200
# 33500/33500 [==============================] - 87s 3ms/sample - loss: 0.2202 - accuracy: 0.9468
# Epoch 88/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.2147 - accuracy: 0.9484
# Epoch 89/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.2128 - accuracy: 0.9493
# Epoch 90/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.2089 - accuracy: 0.9500
# Epoch 91/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.2057 - accuracy: 0.9508
# Epoch 92/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.2005 - accuracy: 0.9533
# Epoch 93/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1991 - accuracy: 0.9517
# Epoch 94/200
# 33500/33500 [==============================] - 87s 3ms/sample - loss: 0.1888 - accuracy: 0.9547
# Epoch 95/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1860 - accuracy: 0.9556
# Epoch 96/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1886 - accuracy: 0.9549
# Epoch 97/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1812 - accuracy: 0.9573
# Epoch 98/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1833 - accuracy: 0.9561
# Epoch 99/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1791 - accuracy: 0.9557
# Epoch 100/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1756 - accuracy: 0.9586
# Epoch 101/200
# 33500/33500 [==============================] - 87s 3ms/sample - loss: 0.1765 - accuracy: 0.9583
# Epoch 102/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1707 - accuracy: 0.9591
# Epoch 103/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1689 - accuracy: 0.9587
# Epoch 104/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1666 - accuracy: 0.9605
# Epoch 105/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1674 - accuracy: 0.9606
# Epoch 106/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1581 - accuracy: 0.9619
# Epoch 107/200
# 33500/33500 [==============================] - 87s 3ms/sample - loss: 0.1571 - accuracy: 0.9629
# Epoch 108/200
# 33500/33500 [==============================] - 87s 3ms/sample - loss: 0.1540 - accuracy: 0.9619
# Epoch 109/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1531 - accuracy: 0.9631
# Epoch 110/200
# 33500/33500 [==============================] - 87s 3ms/sample - loss: 0.1497 - accuracy: 0.9639
# Epoch 111/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1481 - accuracy: 0.9644
# Epoch 112/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1506 - accuracy: 0.9627
# Epoch 113/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1428 - accuracy: 0.9659
# Epoch 114/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1479 - accuracy: 0.9648
# Epoch 115/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1402 - accuracy: 0.9657
# Epoch 116/200
# 33500/33500 [==============================] - 88s 3ms/sample - loss: 0.1414 - accuracy: 0.9656
# Epoch 117/200
# 33500/33500 [==============================] - 84s 3ms/sample - loss: 0.1336 - accuracy: 0.9675
# Epoch 118/200
# 33500/33500 [==============================] - 84s 2ms/sample - loss: 0.1364 - accuracy: 0.9656
# Epoch 119/200
# 33500/33500 [==============================] - 83s 2ms/sample - loss: 0.1376 - accuracy: 0.9661
# Epoch 120/200
# 33500/33500 [==============================] - 84s 3ms/sample - loss: 0.1362 - accuracy: 0.9661
# Epoch 121/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1338 - accuracy: 0.9670
# Epoch 122/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1311 - accuracy: 0.9682
# Epoch 123/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1317 - accuracy: 0.9667
# Epoch 124/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1234 - accuracy: 0.9689
# Epoch 125/200
# 33500/33500 [==============================] - 87s 3ms/sample - loss: 0.1240 - accuracy: 0.9693
# Epoch 126/200
# 33500/33500 [==============================] - 84s 3ms/sample - loss: 0.1268 - accuracy: 0.9684
# Epoch 127/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1264 - accuracy: 0.9685
# Epoch 128/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1255 - accuracy: 0.9681
# Epoch 129/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1264 - accuracy: 0.9681
# Epoch 130/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1203 - accuracy: 0.9694
# Epoch 131/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1190 - accuracy: 0.9706
# Epoch 132/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1237 - accuracy: 0.9695
# Epoch 133/200
# 33500/33500 [==============================] - 84s 3ms/sample - loss: 0.1171 - accuracy: 0.9693
# Epoch 134/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1140 - accuracy: 0.9721
# Epoch 135/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1155 - accuracy: 0.9717
# Epoch 136/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1151 - accuracy: 0.9716
# Epoch 137/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1143 - accuracy: 0.9717
# Epoch 138/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1144 - accuracy: 0.9705
# Epoch 139/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1118 - accuracy: 0.9708
# Epoch 140/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1073 - accuracy: 0.9729
# Epoch 141/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1127 - accuracy: 0.9715
# Epoch 142/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1091 - accuracy: 0.9715
# Epoch 143/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1049 - accuracy: 0.9739
# Epoch 144/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1088 - accuracy: 0.9715
# Epoch 145/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1050 - accuracy: 0.9729
# Epoch 146/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1081 - accuracy: 0.9713
# Epoch 147/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1032 - accuracy: 0.9740
# Epoch 148/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1064 - accuracy: 0.9723
# Epoch 149/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1057 - accuracy: 0.9732
# Epoch 150/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1011 - accuracy: 0.9744
# Epoch 151/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1035 - accuracy: 0.9728
# Epoch 152/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.1013 - accuracy: 0.9734
# Epoch 153/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.0978 - accuracy: 0.9759
# Epoch 154/200
# 33500/33500 [==============================] - 87s 3ms/sample - loss: 0.0963 - accuracy: 0.9757
# Epoch 155/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.1010 - accuracy: 0.9745
# Epoch 156/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.0959 - accuracy: 0.9756
# Epoch 157/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.0997 - accuracy: 0.9729
# Epoch 158/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0961 - accuracy: 0.9759
# Epoch 159/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.0999 - accuracy: 0.9729
# Epoch 160/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.0923 - accuracy: 0.9762
# Epoch 161/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.0946 - accuracy: 0.9751
# Epoch 162/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0925 - accuracy: 0.9761
# Epoch 163/200
# 33500/33500 [==============================] - 82s 2ms/sample - loss: 0.0910 - accuracy: 0.9763
# Epoch 164/200
# 33500/33500 [==============================] - 84s 3ms/sample - loss: 0.0946 - accuracy: 0.9755
# Epoch 165/200
# 33500/33500 [==============================] - 84s 2ms/sample - loss: 0.0876 - accuracy: 0.9781
# Epoch 166/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0908 - accuracy: 0.9755
# Epoch 167/200
# 33500/33500 [==============================] - 84s 2ms/sample - loss: 0.0922 - accuracy: 0.9752
# Epoch 168/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0888 - accuracy: 0.9767
# Epoch 169/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0872 - accuracy: 0.9769
# Epoch 170/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0883 - accuracy: 0.9769
# Epoch 171/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0903 - accuracy: 0.9767
# Epoch 172/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0862 - accuracy: 0.9779
# Epoch 173/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.0889 - accuracy: 0.9759
# Epoch 174/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0860 - accuracy: 0.9774
# Epoch 175/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0867 - accuracy: 0.9771
# Epoch 176/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0847 - accuracy: 0.9782
# Epoch 177/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0860 - accuracy: 0.9772
# Epoch 178/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0868 - accuracy: 0.9767
# Epoch 179/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0834 - accuracy: 0.9781
# Epoch 180/200
# 33500/33500 [==============================] - 84s 3ms/sample - loss: 0.0815 - accuracy: 0.9783
# Epoch 181/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0856 - accuracy: 0.9776
# Epoch 182/200
# 33500/33500 [==============================] - 84s 3ms/sample - loss: 0.0799 - accuracy: 0.9787
# Epoch 183/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0814 - accuracy: 0.9787
# Epoch 184/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.0818 - accuracy: 0.9783
# Epoch 185/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0783 - accuracy: 0.9793
# Epoch 186/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0811 - accuracy: 0.9775
# Epoch 187/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0807 - accuracy: 0.9776
# Epoch 188/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0833 - accuracy: 0.9770
# Epoch 189/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0775 - accuracy: 0.9790
# Epoch 190/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0801 - accuracy: 0.9788
# Epoch 191/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0792 - accuracy: 0.9784
# Epoch 192/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0810 - accuracy: 0.9777
# Epoch 193/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0785 - accuracy: 0.9791
# Epoch 194/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0753 - accuracy: 0.9799
# Epoch 195/200
# 33500/33500 [==============================] - 86s 3ms/sample - loss: 0.0761 - accuracy: 0.9786
# Epoch 196/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0764 - accuracy: 0.9792
# Epoch 197/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0766 - accuracy: 0.9792
# Epoch 198/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0747 - accuracy: 0.9794
# Epoch 199/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0724 - accuracy: 0.9810
# Epoch 200/200
# 33500/33500 [==============================] - 85s 3ms/sample - loss: 0.0754 - accuracy: 0.9798

# %%
input_array = np.load("a.npy")
output = np.load("b.npy")

# %%
    model = Sequential()
    model.add(LSTM(
        256,1
        input_shape=(input_array.shape[1], input_array.shape[2]),
        return_sequences=True
    ))
    #model.add(Dropout(0.3))
    model.add(LSTM(77))
    #model.add(Dropout(0.3))
    #model.add(LSTM(512))
    #model.add(Dense(256))
    #model.add(Dropout(0.3))
    model.add(Dense(77))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    print(model.summary())
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# unified_lstm_16 (UnifiedLSTM (None, 50, 256)           264192
# _________________________________________________________________
# unified_lstm_17 (UnifiedLSTM (None, 77)                102872
# _________________________________________________________________
# dense_11 (Dense)             (None, 77)                6006
# _________________________________________________________________
# activation_11 (Activation)   (None, 77)                0
# =================================================================
# Total params: 373,070
# Trainable params: 373,070
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
lr_2 = train_network()
# Out:
# Parsing midi_songs/FF8_Shuffle_or_boogie_pc.mid
# Parsing midi_songs/ahead_on_our_way_piano.mid
# Parsing midi_songs/balamb.mid
# Parsing midi_songs/DOS.mid
# Parsing midi_songs/FF3_Battle_(Piano).mid
# Parsing midi_songs/Suteki_Da_Ne_(Piano_Version).mid
# Parsing midi_songs/caitsith.mid
# Parsing midi_songs/sera_.mid
# Parsing midi_songs/ff4-airship.mid
# Parsing midi_songs/ff7themep.mid
# Parsing midi_songs/FFVII_BATTLE.mid
# Parsing midi_songs/electric_de_chocobo.mid
# Parsing midi_songs/Cids.mid
# Parsing midi_songs/FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid
# Parsing midi_songs/AT.mid
# Parsing midi_songs/8.mid
# Parsing midi_songs/sobf.mid
# Parsing midi_songs/redwings.mid
# Parsing midi_songs/roseofmay-piano.mid
# Parsing midi_songs/ff4_piano_collections-main_theme.mid
# Parsing midi_songs/dontbeafraid.mid
# Parsing midi_songs/dayafter.mid
# Parsing midi_songs/FFIX_Piano.mid
# Parsing midi_songs/FFIII_Edgar_And_Sabin_Piano.mid
# Parsing midi_songs/0fithos.mid
# Parsing midi_songs/BlueStone_LastDungeon.mid
# Parsing midi_songs/ff8-lfp.mid
# Parsing midi_songs/rufus.mid
# Parsing midi_songs/Fiend_Battle_(Piano).mid
# Parsing midi_songs/cosmo.mid
# Parsing midi_songs/relmstheme-piano.mid
# Parsing midi_songs/ff11_awakening_piano.mid
# Parsing midi_songs/gerudo.mid
# Parsing midi_songs/Rydia_pc.mid
# Parsing midi_songs/Ff4-BattleLust.mid
# Parsing midi_songs/EyesOnMePiano.mid
# Parsing midi_songs/fortresscondor.mid
# Parsing midi_songs/Still_Alive-1.mid
# Parsing midi_songs/Fyw_piano.mid
# Parsing midi_songs/sandy.mid
# Parsing midi_songs/costadsol.mid
# Parsing midi_songs/decisive.mid
# Parsing midi_songs/braska.mid
# Parsing midi_songs/Gold_Silver_Rival_Battle.mid
# Parsing midi_songs/FF3_Third_Phase_Final_(Piano).mid
# Parsing midi_songs/Eternal_Harvest.mid
# Parsing midi_songs/ff1battp.mid
# Parsing midi_songs/Finalfantasy6fanfarecomplete.mid
# Parsing midi_songs/FFIXQuMarshP.mid
# Parsing midi_songs/bcm.mid
# Train on 26800 samples, validate on 6700 samples
# Epoch 1/200
# 26800/26800 [==============================] - 81s 3ms/sample - loss: 3.8683 - accuracy: 0.0406 - val_loss: 4.1832 - val_accuracy: 0.0269
# Epoch 2/200
# 26800/26800 [==============================] - 87s 3ms/sample - loss: 3.8232 - accuracy: 0.0542 - val_loss: 4.1474 - val_accuracy: 0.0339
# Epoch 3/200
# 26800/26800 [==============================] - 82s 3ms/sample - loss: 3.7275 - accuracy: 0.0863 - val_loss: 4.1742 - val_accuracy: 0.0303
# Epoch 4/200
# 26800/26800 [==============================] - 80s 3ms/sample - loss: 3.6747 - accuracy: 0.0941 - val_loss: 4.2326 - val_accuracy: 0.0278
# Epoch 5/200
# 26800/26800 [==============================] - 80s 3ms/sample - loss: 3.6053 - accuracy: 0.1069 - val_loss: 4.1500 - val_accuracy: 0.0464
# Epoch 6/200
# 26800/26800 [==============================] - 81s 3ms/sample - loss: 3.4977 - accuracy: 0.1284 - val_loss: 4.1486 - val_accuracy: 0.0566
# Epoch 7/200
# 26800/26800 [==============================] - 80s 3ms/sample - loss: 3.3688 - accuracy: 0.1539 - val_loss: 4.1496 - val_accuracy: 0.0573
# Epoch 8/200
# 26800/26800 [==============================] - 79s 3ms/sample - loss: 3.2428 - accuracy: 0.1793 - val_loss: 4.3285 - val_accuracy: 0.0552
# Epoch 9/200
# 26800/26800 [==============================] - 79s 3ms/sample - loss: 3.1154 - accuracy: 0.2042 - val_loss: 4.4462 - val_accuracy: 0.0663
# Epoch 10/200
# 26800/26800 [==============================] - 79s 3ms/sample - loss: 2.9906 - accuracy: 0.2276 - val_loss: 4.3722 - val_accuracy: 0.0648
# Epoch 11/200
# 26800/26800 [==============================] - 75s 3ms/sample - loss: 2.8815 - accuracy: 0.2473 - val_loss: 4.3857 - val_accuracy: 0.0615
# Epoch 12/200
# 26800/26800 [==============================] - 76s 3ms/sample - loss: 2.7683 - accuracy: 0.2666 - val_loss: 4.4592 - val_accuracy: 0.0648
# Epoch 13/200
# 26800/26800 [==============================] - 75s 3ms/sample - loss: 2.6670 - accuracy: 0.2888 - val_loss: 4.5066 - val_accuracy: 0.0651
# Epoch 14/200
# 26800/26800 [==============================] - 76s 3ms/sample - loss: 2.5652 - accuracy: 0.3063 - val_loss: 4.5897 - val_accuracy: 0.0670
# Epoch 15/200
# 26800/26800 [==============================] - 75s 3ms/sample - loss: 2.4645 - accuracy: 0.3316 - val_loss: 4.5672 - val_accuracy: 0.0667
# Epoch 16/200
# 26800/26800 [==============================] - 79s 3ms/sample - loss: 2.3733 - accuracy: 0.3520 - val_loss: 4.6315 - val_accuracy: 0.0733
# Epoch 17/200
# 26800/26800 [==============================] - 84s 3ms/sample - loss: 2.2855 - accuracy: 0.3714 - val_loss: 4.7060 - val_accuracy: 0.0660
# Epoch 18/200
# 26800/26800 [==============================] - 76s 3ms/sample - loss: 2.1956 - accuracy: 0.3940 - val_loss: 4.6781 - val_accuracy: 0.0725
# Epoch 19/200
# 26800/26800 [==============================] - 76s 3ms/sample - loss: 2.1075 - accuracy: 0.4134 - val_loss: 4.8079 - val_accuracy: 0.0676
# Epoch 20/200
# 26800/26800 [==============================] - 74s 3ms/sample - loss: 2.0174 - accuracy: 0.4365 - val_loss: 4.8252 - val_accuracy: 0.0676
# Epoch 21/200
# 26800/26800 [==============================] - 75s 3ms/sample - loss: 1.9273 - accuracy: 0.4587 - val_loss: 4.9634 - val_accuracy: 0.0724
# Epoch 22/200
# 26800/26800 [==============================] - 75s 3ms/sample - loss: 1.8341 - accuracy: 0.4862 - val_loss: 5.0054 - val_accuracy: 0.0748
# Epoch 23/200
# 26800/26800 [==============================] - 75s 3ms/sample - loss: 1.7514 - accuracy: 0.5075 - val_loss: 5.1155 - val_accuracy: 0.0757
# Epoch 24/200
# 26800/26800 [==============================] - 76s 3ms/sample - loss: 1.6694 - accuracy: 0.5329 - val_loss: 5.1150 - val_accuracy: 0.0791
# Epoch 25/200
# 26800/26800 [==============================] - 76s 3ms/sample - loss: 1.5770 - accuracy: 0.5596 - val_loss: 5.1654 - val_accuracy: 0.0781
# Epoch 26/200
# 26800/26800 [==============================] - 75s 3ms/sample - loss: 1.4993 - accuracy: 0.5795 - val_loss: 5.2517 - val_accuracy: 0.0881
# Epoch 27/200
# 26800/26800 [==============================] - 74s 3ms/sample - loss: 1.4230 - accuracy: 0.6010 - val_loss: 5.3094 - val_accuracy: 0.0843
# Epoch 28/200
# 26800/26800 [==============================] - 87s 3ms/sample - loss: 1.3506 - accuracy: 0.6256 - val_loss: 5.4623 - val_accuracy: 0.0852
# Epoch 29/200
# 26800/26800 [==============================] - 83s 3ms/sample - loss: 1.2752 - accuracy: 0.6445 - val_loss: 5.5448 - val_accuracy: 0.0872
# Epoch 30/200
# 26800/26800 [==============================] - 81s 3ms/sample - loss: 1.1993 - accuracy: 0.6666 - val_loss: 5.6759 - val_accuracy: 0.0809
# Epoch 31/200
# 26800/26800 [==============================] - 80s 3ms/sample - loss: 1.1299 - accuracy: 0.6881 - val_loss: 5.7443 - val_accuracy: 0.0842
# Epoch 32/200
# 26800/26800 [==============================] - 78s 3ms/sample - loss: 1.0629 - accuracy: 0.7093 - val_loss: 5.7755 - val_accuracy: 0.0888
# Epoch 33/200
# 26800/26800 [==============================] - 80s 3ms/sample - loss: 1.0051 - accuracy: 0.7272 - val_loss: 5.9157 - val_accuracy: 0.0913
# Epoch 34/200
# 26800/26800 [==============================] - 78s 3ms/sample - loss: 0.9476 - accuracy: 0.7416 - val_loss: 6.0198 - val_accuracy: 0.0984
# Epoch 35/200
# 26800/26800 [==============================] - 75s 3ms/sample - loss: 0.8921 - accuracy: 0.7573 - val_loss: 6.0449 - val_accuracy: 0.0928
# Epoch 36/200
# 26800/26800 [==============================] - 77s 3ms/sample - loss: 0.8397 - accuracy: 0.7729 - val_loss: 6.1716 - val_accuracy: 0.1009
# Epoch 37/200
# 26800/26800 [==============================] - 86s 3ms/sample - loss: 0.7907 - accuracy: 0.7849 - val_loss: 6.2243 - val_accuracy: 0.0972
# Epoch 38/200
# 26800/26800 [==============================] - 92s 3ms/sample - loss: 0.7416 - accuracy: 0.8010 - val_loss: 6.3727 - val_accuracy: 0.1004
# Epoch 39/200
# 26800/26800 [==============================] - 84s 3ms/sample - loss: 0.7027 - accuracy: 0.8086 - val_loss: 6.4241 - val_accuracy: 0.1048
# Epoch 40/200
# 26800/26800 [==============================] - 78s 3ms/sample - loss: 0.6551 - accuracy: 0.8247 - val_loss: 6.6445 - val_accuracy: 0.1037
# Epoch 41/200
# 25920/26800 [============================>.] - ETA: 2s - loss: 0.6159 - accuracy: 0.8356
